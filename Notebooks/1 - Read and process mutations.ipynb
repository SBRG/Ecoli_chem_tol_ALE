# %% [markdown]
# # Processing mutations

# %% [markdown]
# The variant calls from the BreSeq pipeline are parsed and analysed. All strains with _mutX_ mutations are excluded as they accumulate SNPs at a very high rate, masking interesting mutations.
#
# Mutations that are present in all strains are also excluded as they have most likely also been in the background strain, prior to the evolution experiments.

# %%
import pandas as pd
import json
import copy
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
compounds = ["HMDA", "putrescine", "1,2-propanediol", "2,3-butanediol", "glutarate", "adipate", "hexanoate", "octanoate", "coumarate", "isobutyrate", "butanol"]

mapping = pd.read_csv("../Data/Mutation_data/Variant_calls/mapping.csv", header=None)
compound_mapping = {
    1: "butanol",
    2: "glutarate",
    3: "coumarate",
    5: "HMDA",
    6: "putrescine",
    7: "adipate",
    8: "isobutyrate",
    9: "hexanoate",
    10: "2,3-butanediol",
    11: "1,2-propanediol",
    12: "octanoate"
}
rev_compound_mapping = {v: k for k, v in compound_mapping.items()}

code_to_compound = {
    "BUT": "butanol",
    "GLUT": "glutarate",
    "COUM": "coumarate",
    "HMDA": "HMDA",
    "PUTR": "putrescine",
    "ADIP": "adipate",
    "IBUA": "isobutyrate",
    "HEXA": "hexanoate",
    "23BD": "2,3-butanediol",
    "12PD": "1,2-propanediol",
    "OCTA": "octanoate"
}
comp_to_code = {v: k for k, v in code_to_compound.items()}

# %% [markdown]
# Generate a mutation id from the information from BreSeq.

# %%
def generate_mut_id(row):
    typ = row["Mutation Type"]
    pos = str(int(row["Position"].replace(",", "")))
    if typ == "SNP":
        last = row["Sequence Change"][-1]
    elif typ == "DEL":
        if "(" in row["Sequence Change"]:
            last = str(len(row["Sequence Change"].split(")")[0][1:]))
        else:
            last = str(int(row["Sequence Change"][1:-3].replace(",", "")))
    elif typ == "INS":
        if "(" in row["Sequence Change"]:
            last = row["Sequence Change"].split(")")[0][1:]
        else:
            last = row["Sequence Change"][1:]
    elif typ == "MOB":
        fields = row["Sequence Change"].split("\xa0")
        last = fields[0] + "-" + fields[2][1:]
    elif typ == "DUP":
        times = row["Sequence Change"].split("x")[-1]
        size = row["Sequence Change"].split(" bp ")[0]
        last = size + "_" + times
    else:
        last = ""
    return "-".join((typ, pos, last))

# %% [markdown]
# Convert the strain code from the breseq results to the real strain names using the mapping file.

# %%
def strain_code_to_name(strain_code, compound):
    compound_num = rev_compound_mapping[compound]
    fields = strain_code.split(" ")[-4:]
    fields = [f[1:] for f in fields]
    code = (int(fields[0]), int(fields[2]), int(fields[3]))
    strain = mapping[mapping[0] == compound_num].groupby(by=[1, 2, 3]).first().loc[code][4]
    return strain

# %%
def convert_to_int(string):
    if string[0] == "‑": # Weird non-standard minus sign
        string = "-" + string[1:] # Replace with normal minus sign
    return int(string)

def pick_gene(rel_coords):
    """Given relative coordinates of an intergenic mutation, pick the gene that is closest downstream"""
    if min(rel_coords) > 0:
        return None
    elif max(rel_coords) <= 0:
        if rel_coords[0] > rel_coords[1]:
            return 0
        else:
            return 1
    elif rel_coords[0] <= 0:
        return 0
    elif rel_coords[1] <= 0:
        return 1
    else:
        raise RuntimeError("What else is there?")

# %%
excluded_mutations = {
    'DEL-1299499-1199', # Randomly called across populations DEL ychE/oppA intergenic(+254/-485)
}

# %%
mapping
# Out:
#       0  1  2  3         4
# 0     1  1  1  1    BUT1-2
# 1     1  1  2  1    BUT1-3
# 2     1  1  3  1    BUT1-5
# 3     1  2  1  1    BUT2-9
# 4     1  3  1  1    BUT3-3
# ..   .. .. .. ..       ...
# 228  12  6  1  1   OCTA7-2
# 229  12  6  2  1   OCTA7-9
# 230  12  6  3  1  OCTA7-10
# 231  12  7  1  1   OCTA8-5
# 232  12  7  2  1   OCTA8-7
#
# [233 rows x 5 columns]

# %%
strain_to_muts = {}
mut_to_genes = {}
mut_to_change = {}

for comp in compounds:
    df = pd.read_csv("../Data/Mutation_data/Variant_calls/%s.csv" % comp)
    df["mut_id"] = df.apply(generate_mut_id, 1)
    
    for idx, row in df.iterrows():
        genes = row["Gene"]
        if "genes" in genes:
            genes = genes.split("genes")[-1] # Fix inconsistent format for large deletions
        genes = genes.split(", ")
        genes = [gene.strip("[] >") for gene in genes]
        change = row["Protein change"]
        if isinstance(change, str) and change.startswith("intergenic"):
            nums = change.split("(")[1][:-1].split("/")
            nums = convert_to_int(nums[0]), convert_to_int(nums[1])
            nearest = pick_gene(nums)
            if nearest is None:
                genes = []
            else:
                genes = [genes[nearest]]
                
        mut_id = row["mut_id"]
        mut_to_genes[mut_id] = genes
        mut_to_change[mut_id] = change
        
    for strain_code in df.columns[10:]:
        if strain_code == "mut_id":
            continue
        strain = strain_code_to_name(strain_code, comp)
        if strain.endswith("-rerun"):
            strain = strain[:-6]

        muts = list(df[df[strain_code] == 1]["mut_id"])
        strain_to_muts[strain] = set(muts) #- excluded_mutations

# %%
df
# Out:
#      Position Mutation Type Sequence Change  \
# 0      19,818           DUP     697 bp x3.4
# 1      82,594           SNP             T→G
# 2     949,006           SNP             T→G
# 3   1,299,499           DEL       Δ1,199 bp
# 4   1,356,672           SNP             A→G
# 5   1,392,752           DEL       Δ3,292 bp
# 6   1,394,081           DEL           Δ2 bp
# 7   1,606,886           DEL      Δ11,558 bp
# 8   1,618,281           DEL           Δ1 bp
# 9   1,618,379           INS              +C
# 10  1,618,666           MOB   IS2 (+) +5 bp
# 11  1,618,698           SNP             T→A
# 12  1,618,850           MOB   IS5 (–) +4 bp
# 13  1,673,883           MOB   IS5 (–) +4 bp
# 14  1,674,448           SNP             C→A
# 15  1,903,497           SNP             T→C
# 16  1,907,330           DEL           Δ2 bp
# 17  1,907,343           MOB   IS1 (–) +8 bp
# 18  1,907,448           MOB   IS5 (–) +4 bp
# 19  1,907,611           MOB   IS5 (+) +4 bp
# 20  1,981,720           SNP             G→A
# 21  3,583,450           DUP     702 bp x3.4
# 22  3,583,467           DUP     694 bp x3.3
# 23  3,815,810           DEL           Δ1 bp
# 24  3,815,859           DEL          Δ82 bp
# 25  3,895,843           SNP             A→C
# 26  3,915,089           SNP             G→T
# 27  4,119,238           DEL          Δ18 bp
# 28  4,362,600           INS              +C
# 29  4,400,407           SNP             T→G
# 30  4,634,895           INS              +A
# 31  4,635,048           SNP             A→C
# 32  4,635,114           SNP             A→C
# 33  4,635,159           SNP             C→T
# 34  4,635,196           INS              +G
# 35  4,635,203           SNP             C→T
# 36  4,635,243           SNP             G→T
#
#                                                  Gene  \
# 0                                      [insB1],  insA
# 1                                                leuA
# 2                                                ycaN
# 3                                         ychE,  oppA
# 4                                                sapA
# 5                                [pgrR],  mppA,  ynaI
# 6                                                mppA
# 7   [lsrF],  lsrG,  tam,  yneE,  uxaB,  yneF,  yne...
# 8                                                marC
# 9                                                marC
# 10                                               marC
# 11                                               marC
# 12                                               marC
# 13                                        mdtJ,  tqsA
# 14                                               tqsA
# 15                                               manY
# 16                                               cspC
# 17                                               cspC
# 18                                               yobF
# 19                                        yobF,  yebO
# 20                                               otsB
# 21                            [yrhA],  insA,  [insB1]
# 22                            [yrhA],  insA,  [insB1]
# 23                                         pyrE,  rph
# 24                                      [rph],  [rph]
# 25                                               adeP
# 26                                               glmU
# 27                                               rraA
# 28                                               pheU
# 29                                                hfq
# 30                                                rob
# 31                                                rob
# 32                                                rob
# 33                                                rob
# 34                                                rob
# 35                                                rob
# 36                                                rob
#
#                        Function                                Product  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
# 3                           NaN                                    NaN
# 4                           NaN                                    NaN
# 5                           NaN                                    NaN
# 6                           NaN                                    NaN
# 7                           NaN                                    NaN
# 8                           NaN                                    NaN
# 9                           NaN                                    NaN
# 10                          NaN                                    NaN
# 11                          NaN                                    NaN
# 12                          NaN                                    NaN
# 13                          NaN                                    NaN
# 14                          NaN                                    NaN
# 15                          NaN                                    NaN
# 16                          NaN                                    NaN
# 17                          NaN                                    NaN
# 18  (phenotype; Not classified)  (DUF2527 family heat-induced protein)
# 19                          NaN                                    NaN
# 20                          NaN                                    NaN
# 21                          NaN                                    NaN
# 22                          NaN                                    NaN
# 23                          NaN                                    NaN
# 24                          NaN                                    NaN
# 25                          NaN                                    NaN
# 26                          NaN                                    NaN
# 27                          NaN                                    NaN
# 28                          NaN                                    NaN
# 29                          NaN                                    NaN
# 30                          NaN                                    NaN
# 31                          NaN                                    NaN
# 32                          NaN                                    NaN
# 33                          NaN                                    NaN
# 34                          NaN                                    NaN
# 35                          NaN                                    NaN
# 36                          NaN                                    NaN
#
#    GO Process              GO Component            Protein change  \
# 0         NaN                       NaN               Duplication
# 1         NaN                       NaN           E312D (GAA→GAC)
# 2         NaN                       NaN           N188T (AAT→ACT)
# 3         NaN                       NaN    intergenic (+254/‑485)
# 4         NaN                       NaN           Y147H (TAC→CAC)
# 5         NaN                       NaN              IS5‑mediated
# 6         NaN                       NaN  coding (855‑856/1614 nt)
# 7         NaN                       NaN                       NaN
# 8         NaN                       NaN       coding (628/666 nt)
# 9         NaN                       NaN       coding (530/666 nt)
# 10        NaN                       NaN   coding (239‑243/666 nt)
# 11        NaN                       NaN            I71F (ATT→TTT)
# 12        NaN                       NaN     coding (56‑59/666 nt)
# 13        NaN                       NaN     intergenic (‑382/‑27)
# 14        NaN                       NaN           P179Q (CCG→CAG)
# 15        NaN                       NaN           I139T (ATC→ACC)
# 16        NaN                       NaN   coding (105‑106/210 nt)
# 17        NaN                       NaN     coding (86‑93/210 nt)
# 18         ()  (GO:0005737 - cytoplasm)   coding (141‑144/144 nt)
# 19        NaN                       NaN     intergenic (‑20/+647)
# 20        NaN                       NaN           A223V (GCA→GTA)
# 21        NaN                       NaN               Duplication
# 22        NaN                       NaN               Duplication
# 23        NaN                       NaN      intergenic (‑42/+24)
# 24        NaN                       NaN                       NaN
# 25        NaN                       NaN           V256G (GTG→GGG)
# 26        NaN                       NaN            H38N (CAT→AAT)
# 27        NaN                       NaN     coding (76‑93/486 nt)
# 28        NaN                       NaN      noncoding (27/76 nt)
# 29        NaN                       NaN            D40E (GAT→GAG)
# 30        NaN                       NaN       coding (416/870 nt)
# 31        NaN                       NaN            F88C (TTT→TGT)
# 32        NaN                       NaN            L66R (CTA→CGA)
# 33        NaN                       NaN            G51D (GGC→GAC)
# 34        NaN                       NaN       coding (115/870 nt)
# 35        NaN                       NaN            W36* (TGG→TGA)
# 36        NaN                       NaN            S23* (TCG→TAG)
#
#     TOL 20C nbutanol A0 F0 I1 R1  ...  TOL 20C nbutanol A5 F50 I2 R1  \
# 0                            NaN  ...                            NaN
# 1                            NaN  ...                            NaN
# 2                            NaN  ...                            NaN
# 3                            NaN  ...                            1.0
# 4                            NaN  ...                            NaN
# 5                            NaN  ...                            NaN
# 6                            NaN  ...                            NaN
# 7                            NaN  ...                            NaN
# 8                            NaN  ...                            NaN
# 9                            NaN  ...                            NaN
# 10                           NaN  ...                            1.0
# 11                           NaN  ...                            NaN
# 12                           NaN  ...                            NaN
# 13                           NaN  ...                            NaN
# 14                           NaN  ...                            NaN
# 15                           NaN  ...                            1.0
# 16                           NaN  ...                            NaN
# 17                           NaN  ...                            1.0
# 18                           NaN  ...                            NaN
# 19                           NaN  ...                            NaN
# 20                           NaN  ...                            NaN
# 21                           NaN  ...                            NaN
# 22                           NaN  ...                            NaN
# 23                           NaN  ...                            1.0
# 24                           NaN  ...                            NaN
# 25                           NaN  ...                            NaN
# 26                           NaN  ...                            1.0
# 27                           NaN  ...                            NaN
# 28                           NaN  ...                            NaN
# 29                           NaN  ...                            NaN
# 30                           NaN  ...                            NaN
# 31                           NaN  ...                            NaN
# 32                           NaN  ...                            NaN
# 33                           NaN  ...                            1.0
# 34                           NaN  ...                            NaN
# 35                           NaN  ...                            NaN
# 36                           NaN  ...                            NaN
#
#     TOL 20C nbutanol A6 F50 I1 R1  TOL 20C nbutanol A6 F50 I2 R1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             1.0                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             1.0                            1.0
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            1.0                            1.0
# 16                            NaN                            NaN
# 17                            NaN                            NaN
# 18                            1.0                            1.0
# 19                            NaN                            NaN
# 20                            NaN                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            1.0                            1.0
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                            NaN                            NaN
# 28                            NaN                            NaN
# 29                            NaN                            NaN
# 30                            NaN                            NaN
# 31                            NaN                            NaN
# 32                            NaN                            NaN
# 33                            NaN                            NaN
# 34                            NaN                            NaN
# 35                            NaN                            NaN
# 36                            1.0                            1.0
#
#     TOL 20C nbutanol A6 F50 I3 R1  TOL 20C nbutanol A7 F50 I1 R1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             1.0                            1.0
# 4                             NaN                            NaN
# 5                             NaN                            1.0
# 6                             NaN                            NaN
# 7                             1.0                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            1.0                            1.0
# 16                            NaN                            NaN
# 17                            NaN                            NaN
# 18                            1.0                            NaN
# 19                            NaN                            1.0
# 20                            NaN                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            1.0                            1.0
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                            NaN                            NaN
# 28                            NaN                            NaN
# 29                            NaN                            NaN
# 30                            NaN                            NaN
# 31                            NaN                            NaN
# 32                            NaN                            NaN
# 33                            NaN                            NaN
# 34                            NaN                            NaN
# 35                            NaN                            1.0
# 36                            1.0                            NaN
#
#     TOL 20C nbutanol A7 F50 I2 R1  TOL 20C nbutanol A7 F50 I3 R1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             1.0                            NaN
# 4                             NaN                            NaN
# 5                             1.0                            1.0
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            1.0                            1.0
# 16                            NaN                            NaN
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            1.0                            1.0
# 20                            NaN                            NaN
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            1.0                            1.0
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                            NaN                            NaN
# 28                            NaN                            NaN
# 29                            NaN                            NaN
# 30                            NaN                            NaN
# 31                            NaN                            NaN
# 32                            NaN                            NaN
# 33                            NaN                            NaN
# 34                            NaN                            NaN
# 35                            1.0                            1.0
# 36                            NaN                            NaN
#
#     TOL 20C nbutanol A8 F50 I1 R1  TOL 20C nbutanol A8 F50 I2 R1  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             1.0                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             1.0                            1.0
# 10                            NaN                            NaN
# 11                            NaN                            NaN
# 12                            NaN                            NaN
# 13                            NaN                            NaN
# 14                            NaN                            NaN
# 15                            1.0                            1.0
# 16                            NaN                            NaN
# 17                            NaN                            NaN
# 18                            NaN                            NaN
# 19                            NaN                            NaN
# 20                            NaN                            1.0
# 21                            NaN                            NaN
# 22                            NaN                            NaN
# 23                            1.0                            1.0
# 24                            NaN                            NaN
# 25                            NaN                            NaN
# 26                            NaN                            NaN
# 27                            1.0                            1.0
# 28                            NaN                            NaN
# 29                            NaN                            NaN
# 30                            NaN                            NaN
# 31                            1.0                            1.0
# 32                            NaN                            NaN
# 33                            NaN                            NaN
# 34                            NaN                            NaN
# 35                            NaN                            NaN
# 36                            NaN                            NaN
#
#                  mut_id
# 0     DUP-19818-697_3.4
# 1           SNP-82594-G
# 2          SNP-949006-G
# 3      DEL-1299499-1199
# 4         SNP-1356672-G
# 5      DEL-1392752-3292
# 6         DEL-1394081-2
# 7     DEL-1606886-11558
# 8         DEL-1618281-1
# 9         INS-1618379-C
# 10    MOB-1618666-IS2-5
# 11        SNP-1618698-A
# 12    MOB-1618850-IS5-4
# 13    MOB-1673883-IS5-4
# 14        SNP-1674448-A
# 15        SNP-1903497-C
# 16        DEL-1907330-2
# 17    MOB-1907343-IS1-8
# 18    MOB-1907448-IS5-4
# 19    MOB-1907611-IS5-4
# 20        SNP-1981720-A
# 21  DUP-3583450-702_3.4
# 22  DUP-3583467-694_3.3
# 23        DEL-3815810-1
# 24       DEL-3815859-82
# 25        SNP-3895843-C
# 26        SNP-3915089-T
# 27       DEL-4119238-18
# 28        INS-4362600-C
# 29        SNP-4400407-G
# 30        INS-4634895-A
# 31        SNP-4635048-C
# 32        SNP-4635114-C
# 33        SNP-4635159-T
# 34        INS-4635196-G
# 35        SNP-4635203-T
# 36        SNP-4635243-T
#
# [37 rows x 31 columns]

# %%
# Save the protein effect of all SNP mutations
mut_effects = {}
for mut, change in mut_to_change.items():
    typ = mut.split("-")[0]
    if typ == "SNP":
        if "intergenic" in change:
            effect = "intergenic"
        elif "pseudogene" in change:
            effect = "pseudogene"
        else:
            subs = change.split()[0]
            effect = subs
    else:
        effect = ""
        if change == change and typ != "DUP":
            effect = change.split()[0]
            # print(typ, change)
    mut_effects[mut] = (typ, effect)
    
with open("../Data/Mutation_data/Mutation_effects.json", "w") as outfile:
    json.dump(mut_effects, outfile)

# %%
print(
    "There are",
    len(strain_to_muts),
    "strains with a total of",
    len(set.union(*strain_to_muts.values())), "mutations."
)
# Out:
# There are 224 strains with a total of 3753 mutations.

# %%
# Create overview table of mutations in all strains
mut_df = pd.DataFrame({s: {m: 1 for m in muts} for s, muts in strain_to_muts.items()}).fillna(0).astype("int")
mut_df.to_csv("../Data/Mutation_data/strain_mutation_table.tsv", sep="\t")

# %%
strain_to_genes = {}

# Add genes that are specifically mutated (mutation only has 1 gene target)
for strain, muts in strain_to_muts.items():
    for mut in muts:
        if len(mut_to_genes[mut]) == 1:
            strain_to_genes.setdefault(strain, []).append(mut_to_genes[mut][0])
            
strain_to_genes = {k: set(v) for k, v in strain_to_genes.items()}

certain_mutations = {
    comp: set.union(*(v for k, v in strain_to_genes.items() if k.startswith(comp))) for comp in code_to_compound
}
strain_to_all_genes = copy.deepcopy(strain_to_genes)

# For mutations that affect multiple genes: only add genes that are already mutated in strains from that compound
# (or mutator genes)
for comp in code_to_compound:
    for strain in (s for s in strain_to_muts if s.startswith(comp)):
        for mut in strain_to_muts[strain]:
            if mut.startswith("DUP"):
                continue
            if len(mut_to_genes[mut]) > 1:
                for gene in mut_to_genes[mut]:
                    strain_to_all_genes[strain].add(gene)
                    if gene in certain_mutations[comp] or gene.startswith("mut"):
                        strain_to_genes[strain].add(gene)

# %%
certain_mutations
# Out:
# {'BUT': {'adeP',
#   'cspC',
#   'glmU',
#   'hfq',
#   'leuA',
#   'manY',
#   'marC',
#   'mppA',
#   'oppA',
#   'otsB',
#   'pheU',
#   'pyrE',
#   'rob',
#   'rraA',
#   'sapA',
#   'tqsA',
#   'ycaN',
#   'yobF'},
#  'GLUT': {'aceK',
#   'csiD',
#   'cspE',
#   'dkgA',
#   'fruB',
#   'greA',
#   'hcaD',
#   'hofM',
#   'insG',
#   'kgtP',
#   'lit',
#   'lldR',
#   'mprA',
#   'nagA',
#   'nagC',
#   'nohQ',
#   'oppA',
#   'polB',
#   'proV',
#   'proX',
#   'ravA',
#   'rclB',
#   'rlmI',
#   'rnb',
#   'rnt',
#   'roxA',
#   'rplM',
#   'rpoB',
#   'rpoC',
#   'rrlA',
#   'rrlC',
#   'rsmC',
#   'rspA',
#   'sapC',
#   'sdaC',
#   'spoT',
#   'sspA',
#   'ssuA',
#   'tdcD',
#   'tomB',
#   'uvrD',
#   'wzzE',
#   'yagU',
#   'ybeF',
#   'ydfI',
#   'yfdC',
#   'yfjL',
#   'ygjP',
#   'yhfA',
#   'yhfX',
#   'yhiL',
#   'yiaT',
#   'yliE',
#   'yobF',
#   'ytfR'},
#  'COUM': {'atpI',
#   'ccmA',
#   'dacA',
#   'dcd',
#   'epmB',
#   'fimC',
#   'fimD',
#   'focA',
#   'glnG',
#   'hns',
#   'manY',
#   'mgrB',
#   'mprA',
#   'mrdA',
#   'murC',
#   'nadR',
#   'nusA',
#   'ompN',
#   'oppA',
#   'polB',
#   'prlF',
#   'pyrE',
#   'rhaT',
#   'rho',
#   'rnb',
#   'rpoA',
#   'rpoB',
#   'rpoC',
#   'rpsG',
#   'sapC',
#   'sapF',
#   'thrA',
#   'tufA',
#   'ycfQ',
#   'ydiJ',
#   'ydjH',
#   'yecT',
#   'yfiN',
#   'yhgE',
#   'yhjK',
#   'yjiP',
#   'yphF',
#   'ypjA',
#   'ypjC'},
#  'HMDA': {'aat',
#   'agaS',
#   'aldA',
#   'alx',
#   'ampC',
#   'amtB',
#   'anmK',
#   'araA',
#   'arnA',
#   'artP',
#   'ascG',
#   'atoS',
#   'atpI',
#   'bax',
#   'bcsB',
#   'bglB',
#   'bglH',
#   'bioA',
#   'cbdB',
#   'cdd',
#   'chbF',
#   'clcB',
#   'clpX',
#   'cmoA',
#   'cnu',
#   'creB',
#   'cynR',
#   'dadA',
#   'dcuC',
#   'dgkA',
#   'dmsA',
#   'dnaE',
#   'dppA',
#   'emrD',
#   'entS',
#   'envY',
#   'essQ',
#   'fadL',
#   'fdhD',
#   'fimH',
#   'flgE',
#   'frmR',
#   'frsA',
#   'frwC',
#   'garK',
#   'gatY',
#   'gdhA',
#   'glcF',
#   'glsA',
#   'gnsB',
#   'gntU',
#   'groL',
#   'hdfR',
#   'hemC',
#   'hisI',
#   'htpX',
#   'hycA',
#   'hycG',
#   'hycH',
#   'icd',
#   'idnD',
#   'ilvG',
#   'insO',
#   'katE',
#   'katG',
#   'kup',
#   'leuA',
#   'lexA',
#   'lgt',
#   'lhr',
#   'lplA',
#   'malI',
#   'mdtK',
#   'metB',
#   'mgtA',
#   'mhpR',
#   'mpl',
#   'mreB',
#   'mukB',
#   'mutS',
#   'mutT',
#   'mutY',
#   'nadR',
#   'nagA',
#   'nagC',
#   'nikA',
#   'nrfD',
#   'nusA',
#   'oppA',
#   'paaH',
#   'panD',
#   'paoB',
#   'parE',
#   'patA',
#   'pepA',
#   'phnH',
#   'phoQ',
#   'pncB',
#   'pnp',
#   'ppsA',
#   'prfB',
#   'proV',
#   'pspF',
#   'pstB',
#   'ptsP',
#   'purL',
#   'puuC',
#   'pyrE',
#   'radA',
#   'rarD',
#   'recA',
#   'recB',
#   'recG',
#   'rhaA',
#   'rlmG',
#   'rnb',
#   'rnt',
#   'rph',
#   'rpoB',
#   'rpoC',
#   'rpoD',
#   'rpsA',
#   'rpsG',
#   'rsmA',
#   'rsmG',
#   'sapD',
#   'sdhA',
#   'secF',
#   'serA',
#   'sodC',
#   'speA',
#   'spoT',
#   'sspA',
#   'stpA',
#   'sucA',
#   'thiL',
#   'thyA',
#   'tnaB',
#   'trkA',
#   'uraA',
#   'uvrA',
#   'wbbK',
#   'wecB',
#   'xapA',
#   'xapR',
#   'yaaI',
#   'yaaJ',
#   'yadN',
#   'yaiC',
#   'ybcK',
#   'ybeU',
#   'ybeX',
#   'ybhA',
#   'ybhK',
#   'yccT',
#   'yceK',
#   'ycgH',
#   'yciW',
#   'ydaY',
#   'ydbC',
#   'ydbJ',
#   'ydcK',
#   'ydcR',
#   'ydfU',
#   'ydgJ',
#   'ydgU',
#   'ydhP',
#   'yecJ',
#   'yegV',
#   'yfcH',
#   'yfdX',
#   'yfeO',
#   'ygbI',
#   'ygbT',
#   'ygcP',
#   'ygdH',
#   'ygeG',
#   'ygfK',
#   'yghE',
#   'ygiC',
#   'ygiD',
#   'ygjI',
#   'yhbE',
#   'yhfZ',
#   'yhhW',
#   'yhhZ',
#   'yhjG',
#   'yiiX',
#   'yjcS',
#   'yjeH',
#   'yjfI',
#   'yjfJ',
#   'yjfP',
#   'ymfE',
#   'ymiA',
#   'yncH',
#   'yneO',
#   'ynjE',
#   'yphA',
#   'yphG',
#   'yqcC',
#   'yqjA',
#   'yraK',
#   'yrbL',
#   'yrhB',
#   'yrhC',
#   'zapD'},
#  'PUTR': {'argG',
#   'clpX',
#   'cmtB',
#   'cspC',
#   'edd',
#   'fliK',
#   'fliR',
#   'glnE',
#   'glyX',
#   'icdC',
#   'intE',
#   'iscR',
#   'leuL',
#   'lexA',
#   'mdtJ',
#   'mrdB',
#   'mreB',
#   'murA',
#   'nagC',
#   'nmpC',
#   'nusA',
#   'nusG',
#   'oppA',
#   'proV',
#   'proX',
#   'pstA',
#   'pstS',
#   'pykF',
#   'pyrE',
#   'rph',
#   'rpoB',
#   'rpoC',
#   'rpoD',
#   'rpsA',
#   'rpsG',
#   'sfmH',
#   'spoT',
#   'sspA',
#   'stpA',
#   'tdcR',
#   'tolA',
#   'tyrB',
#   'waaS',
#   'ybcK',
#   'ycgB',
#   'yeaR',
#   'yedP',
#   'yfjW',
#   'ygaC',
#   'yieK',
#   'yjcF',
#   'yjhG',
#   'yobF',
#   'yphF',
#   'ytfR'},
#  'ADIP': {'abgA',
#   'aceA',
#   'aceF',
#   'acs',
#   'add',
#   'adeQ',
#   'adhE',
#   'agaI',
#   'agaS',
#   'alaE',
#   'alaS',
#   'allC',
#   'allD',
#   'allS',
#   'alsA',
#   'amiB',
#   'amn',
#   'amtB',
#   'araG',
#   'arcB',
#   'arnF',
#   'aroH',
#   'arpA',
#   'arpB',
#   'artI',
#   'artQ',
#   'asnS',
#   'asnV',
#   'aspA',
#   'atoC',
#   'bacA',
#   'bamE',
#   'bepA',
#   'bioA',
#   'birA',
#   'blr',
#   'bluF',
#   'bluR',
#   'caiB',
#   'cbpA',
#   'cbrC',
#   'chiA',
#   'cho',
#   'cirA',
#   'citA',
#   'clpB',
#   'cmk',
#   'cof',
#   'csgA',
#   'cusA',
#   'cydA',
#   'cysB',
#   'dcp',
#   'dcuS',
#   'dcyD',
#   'ddpF',
#   'dgoK',
#   'dgt',
#   'djlB',
#   'dnaN',
#   'elfA',
#   'entH',
#   'eptA',
#   'eptC',
#   'era',
#   'eutR',
#   'evgS',
#   'fadB',
#   'fdhF',
#   'fdnG',
#   'fdoG',
#   'fecA',
#   'feoB',
#   'fimC',
#   'fimI',
#   'fkpA',
#   'flgE',
#   'fliD',
#   'fliE',
#   'fliH',
#   'fliN',
#   'flk',
#   'fnr',
#   'frc',
#   'ftsK',
#   'ftsW',
#   'gadA',
#   'galE',
#   'gatZ',
#   'gcd',
#   'gcl',
#   'ghrA',
#   'ghxQ',
#   'glcA',
#   'glf',
#   'glgP',
#   'glnG',
#   'glpC',
#   'glpK',
#   'glrK',
#   'gltP',
#   'gmhA',
#   'gmhB',
#   'gpt',
#   'gshA',
#   'gsiB',
#   'gspD',
#   'gyrA',
#   'hdeD',
#   'hemA',
#   'hemG',
#   'hns',
#   'hpt',
#   'hrpA',
#   'hrpB',
#   'hscA',
#   'hsdR',
#   'hybF',
#   'hycB',
#   'iaaA',
#   'icd',
#   'idnR',
#   'insC1',
#   'insH1',
#   'insI1',
#   'intR',
#   'ispB',
#   'kefB',
#   'kgtP',
#   'lacY',
#   'lepB',
#   'leuA',
#   'leuE',
#   'lgoT',
#   'ligA',
#   'lldD',
#   'lptC',
#   'lsrG',
#   'luxS',
#   'malP',
#   'malQ',
#   'malT',
#   'marR',
#   'mdh',
#   'mdtC',
#   'mdtE',
#   'mdtM',
#   'menB',
#   'menF',
#   'metL',
#   'mhpA',
#   'miaA',
#   'mltD',
#   'mngR',
#   'modE',
#   'mreB',
#   'mreD',
#   'mscK',
#   'mtlA',
#   'murQ',
#   'mutT',
#   'nadE',
#   'nagA',
#   'nagC',
#   'nanR',
#   'nanT',
#   'narX',
#   'nirB',
#   'nlpI',
#   'nmpC',
#   'nrdD',
#   'nupG',
#   'nusA',
#   'nusB',
#   'ompC',
#   'ompF',
#   'opgB',
#   'opgD',
#   'oppA',
#   'otsA',
#   'paaZ',
#   'patD',
#   'pcnB',
#   'pdxJ',
#   'pflC',
#   'pgm',
#   'pldA',
#   'plsB',
#   'pnp',
#   'pntA',
#   'potA',
#   'ppc',
#   'ppx',
#   'prfA',
#   'prkB',
#   'proQ',
#   'proV',
#   'proW',
#   'prpB',
#   'prpD',
#   'prpE',
#   'pstS',
#   'ptsP',
#   'purL',
#   'pykF',
#   'pyrE',
#   'quuD',
#   'rapA',
#   'rarD',
#   'rcsB',
#   'rcsF',
#   'rdgC',
#   'rffG',
#   'rhaB',
#   'rhaD',
#   'ribF',
#   'rlmD',
#   'rluC',
#   'rluE',
#   'rnhB',
#   'rnlA',
#   'rnt',
#   'rph',
#   'rpiB',
#   'rplA',
#   'rpoB',
#   'rpoC',
#   'rpoS',
#   'rpsQ',
#   'rrsG',
#   'rseP',
#   'rtcR',
#   'sbcB',
#   'sbcD',
#   'scpA',
#   'selA',
#   'sgcC',
#   'sgrR',
#   'slmA',
#   'sodA',
#   'speA',
#   'speC',
#   'speE',
#   'spoT',
#   'srmB',
#   'sseA',
#   'sspA',
#   'ssuC',
#   'sxy',
#   'talA',
#   'tamB',
#   'tdcD',
#   'tdh',
#   'thiP',
#   'thyA',
#   'tmcA',
#   'treF',
#   'trg',
#   'trpB',
#   'tsgA',
#   'tsx',
#   'tyrB',
#   'ubiE',
#   'ushA',
#   'uspA',
#   'uvrB',
#   'uvrY',
#   'waaG',
#   'wbbK',
#   'wcaI',
#   'wecA',
#   'wecB',
#   'wzzB',
#   'xapR',
#   'yaaU',
#   'yaeF',
#   'yaeI',
#   'yaeR',
#   'yafS',
#   'yagI',
#   'yagL',
#   'yahG',
#   'ybdL',
#   'ybfA',
#   'ybfG',
#   'ybgA',
#   'ybiI',
#   'ybjC',
#   'ybjE',
#   'ybjL',
#   'ycaL',
#   'yccM',
#   'ycfH',
#   'ycgG',
#   'ycgV',
#   'yciO',
#   'yciV',
#   'ycjG',
#   'ycjP',
#   'ydaM',
#   'ydbD',
#   'ydcD',
#   'ydcP',
#   'ydeE',
#   'ydhC',
#   'ydhP',
#   'ydhS',
#   'ydjH',
#   'yeaI',
#   'yeaK',
#   'yeaR',
#   'yebF',
#   'yebZ',
#   'yecR',
#   'yecS',
#   'yedP',
#   'yeeE',
#   'yeeJ',
#   'yehA',
#   'yehD',
#   'yehU',
#   'yehY',
#   'yeiQ',
#   'yejK',
#   'yfaE',
#   'yfaL',
#   'yfcH',
#   'yfcI',
#   'yfeA',
#   'yffL',
#   'yfgO',
#   'yfhM',
#   'yfjK',
#   'yfjX',
#   'ygbK',
#   'ygeI',
#   'ygfK',
#   'yggD',
#   'yghA',
#   'yghF',
#   'yhaB',
#   'yhaC',
#   'yhcA',
#   'yhdP',
#   'yhdZ',
#   'yhiL',
#   'yhiS',
#   'yhjJ',
#   'yhjK',
#   'yibA',
#   'yibI',
#   'yicC',
#   'yicI',
#   'yidP',
#   'yieP',
#   'yifK',
#   'yihF',
#   'yihU',
#   'yihY',
#   'yiiE',
#   'yjbG',
#   'yjcC',
#   'yjcH',
#   'yjcS',
#   'yjdP',
#   'yjfY',
#   'yjhI',
#   'yjhR',
#   'yjiH',
#   'yjiK',
#   'yjiT',
#   'yjjI',
#   'ykfK',
#   'ymfI',
#   'ymfJ',
#   'ynbG',
#   'yncD',
#   'yneO',
#   'ynfC',
#   'ynfE',
#   'ynfN',
#   'ynjC',
#   'ynjH',
#   'yoaD',
#   'ypfH',
#   'yphC',
#   'yphH',
#   'yqgF',
#   'yrdD',
#   'zwf'},
#  'IBUA': {'allA',
#   'argE',
#   'asnA',
#   'bglF',
#   'bglG',
#   'caiC',
#   'chbB',
#   'cheR',
#   'dmsA',
#   'gadE',
#   'gatC',
#   'gcd',
#   'glnS',
#   'glyQ',
#   'hemC',
#   'hsdR',
#   'ilvH',
#   'ilvN',
#   'infA',
#   'infB',
#   'insA',
#   'lpxP',
#   'lrhA',
#   'lysU',
#   'manY',
#   'mntH',
#   'murG',
#   'mutT',
#   'nadK',
#   'nudK',
#   'oppA',
#   'osmB',
#   'pepQ',
#   'prfA',
#   'ptsP',
#   'pykF',
#   'pyrE',
#   'rhsD',
#   'rlmE',
#   'rne',
#   'rplJ',
#   'rpoB',
#   'rpoC',
#   'rpoS',
#   'rpsC',
#   'rpsD',
#   'rpsI',
#   'rpsL',
#   'rrsA',
#   'sad',
#   'safA',
#   'sapA',
#   'sapB',
#   'sapC',
#   'sapD',
#   'sapF',
#   'speA',
#   'srlD',
#   'trkG',
#   'wzc',
#   'xdhA',
#   'xdhD',
#   'yadE',
#   'yaiP',
#   'ybbW',
#   'ydbA',
#   'ydcL',
#   'yedV',
#   'yeeE',
#   'yfaL',
#   'yffB',
#   'yffQ',
#   'ygfI',
#   'yijD',
#   'yjjG',
#   'yjjQ',
#   'yobF'},
#  'HEXA': {'barA',
#   'bioB',
#   'cydA',
#   'dosP',
#   'emrY',
#   'glxK',
#   'hns',
#   'mdtK',
#   'murG',
#   'ompC',
#   'ompR',
#   'opgH',
#   'oppA',
#   'proQ',
#   'prpE',
#   'ptrA',
#   'pykF',
#   'rhmD',
#   'rpoA',
#   'rpoB',
#   'rpoC',
#   'rsd',
#   'rsfS',
#   'sapA',
#   'sapB',
#   'sfmF',
#   'yedP',
#   'yfjL'},
#  '23BD': {'aat',
#   'acnA',
#   'acpP',
#   'acrB',
#   'acrF',
#   'acrR',
#   'acs',
#   'ada',
#   'adeD',
#   'agaI',
#   'alaS',
#   'alr',
#   'anmK',
#   'apbE',
#   'aqpZ',
#   'araJ',
#   'argQ',
#   'aroF',
#   'arpA',
#   'arpB',
#   'artI',
#   'asnB',
#   'astD',
#   'atoB',
#   'atoD',
#   'atpI',
#   'bcsA',
#   'bcsC',
#   'bcsG',
#   'betA',
#   'betB',
#   'bglG',
#   'bioF',
#   'bluR',
#   'cadA',
#   'cbtA',
#   'cheB',
#   'chiQ',
#   'cho',
#   'cirA',
#   'citT',
#   'clpA',
#   'cmoA',
#   'coaE',
#   'cobT',
#   'csgD',
#   'cueR',
#   'cusB',
#   'cusR',
#   'cyaA',
#   'cybB',
#   'cynR',
#   'cynT',
#   'dacA',
#   'dacD',
#   'dadA',
#   'dauA',
#   'dcuS',
#   'ddpC',
#   'deoC',
#   'dgoA',
#   'diaA',
#   'dmsC',
#   'dnaA',
#   'dnaK',
#   'dosP',
#   'dsdX',
#   'eco',
#   'ecpC',
#   'elfA',
#   'elfD',
#   'elfG',
#   'elyC',
#   'emrB',
#   'essD',
#   'etk',
#   'eutB',
#   'eutH',
#   'exuR',
#   'fabH',
#   'fabI',
#   'fadB',
#   'fadE',
#   'fadH',
#   'fadI',
#   'fdhD',
#   'fdoH',
#   'fdrA',
#   'fecB',
#   'fecD',
#   'fecE',
#   'fecR',
#   'fes',
#   'fetB',
#   'ffh',
#   'fhuD',
#   'fimA',
#   'flu',
#   'fmt',
#   'frdB',
#   'frmR',
#   'fryA',
#   'ftsA',
#   'ftsY',
#   'fucI',
#   'fumB',
#   'gabP',
#   'galM',
#   'gcvA',
#   'gcvT',
#   'gfcC',
#   'gfcD',
#   'glgC',
#   'glmU',
#   'glnQ',
#   'glnS',
#   'glpC',
#   'glsB',
#   'gltD',
#   'gltJ',
#   'gntP',
#   'gpmA',
#   'gpmM',
#   'gsiA',
#   'gtrS',
#   'hflK',
#   'hisD',
#   'hrpA',
#   'hsdR',
#   'hycB',
#   'hydN',
#   'hyfB',
#   'hyfF',
#   'iadA',
#   'ilvG',
#   'intR',
#   'iraD',
#   'iraM',
#   'iscR',
#   'ispA',
#   'kduI',
#   'lacZ',
#   'ldtB',
#   'ldtD',
#   'lepA',
#   'leuD',
#   'leuV',
#   'lhgO',
#   'ligA',
#   'lon',
#   'lptD',
#   'lpxA',
#   'lpxK',
#   'lsrD',
#   'maeB',
#   'malI',
#   'malT',
#   'marC',
#   'mcrC',
#   'mdlB',
#   'mdtC',
#   'menE',
#   'mepM',
#   'mepS',
#   'metE',
#   'metJ',
#   'mglB',
#   'mhpF',
#   'minD',
#   'mipA',
#   'mltD',
#   'mngA',
#   'mngB',
#   'mnmA',
#   'mnmE',
#   'mnmG',
#   'mntP',
#   'mprA',
#   'mscS',
#   'mtr',
#   'murB',
#   'murD',
#   'murE',
#   'mutL',
#   'nagC',
#   'nanK',
#   'nemA',
#   'nfo',
#   'nfrB',
#   'nuoE',
#   'nuoG',
#   'nusG',
#   'ompG',
#   'oppA',
#   'oppB',
#   'osmE',
#   'paoC',
#   'patA',
#   'pdxB',
#   'pepA',
#   'pfkB',
#   'pgi',
#   'pgl',
#   'pheA',
#   'pheT',
#   'phnJ',
#   'phnM',
#   'php',
#   'pldB',
#   'polB',
#   'poxB',
#   'pphB',
#   'preA',
#   'prfA',
#   'prmC',
#   'proX',
#   'prpC',
#   'pspD',
#   'purT',
#   'pykA',
#   'pyrE',
#   'qseB',
#   'quuD',
#   'rarD',
#   'ravA',
#   'recB',
#   'recE',
#   'recF',
#   'recJ',
#   'relA',
#   'rep',
#   'rhmD',
#   'rho',
#   'rhsC',
#   'rhsD',
#   'rhsE',
#   'rihA',
#   'rimI',
#   'rluD',
#   'rnb',
#   'rnk',
#   'rodZ',
#   'rpe',
#   'rpoB',
#   'rpoC',
#   'rpoD',
#   'rpsA',
#   'rpsO',
#   'rseB',
#   'rseC',
#   'rsxE',
#   'rtcA',
#   'rutB',
#   'sbcC',
#   'sbmA',
#   'seqA',
#   'sfmH',
#   'sixA',
#   'speB',
#   'speC',
#   'spoT',
#   'sslE',
#   'sspB',
#   'stfR',
#   'tamB',
#   'thiB',
#   'thrS',
#   'tig',
#   'tktB',
#   'tolA',
#   'tolC',
#   'tolR',
#   'topA',
#   'treR',
#   'trmN',
#   'trpB',
#   'truC',
#   'umpH',
#   'umuC',
#   'umuD',
#   'ushA',
#   'uspC',
#   'uspF',
#   'uup',
#   'uvrA',
#   'uvrD',
#   'uxaC',
#   'uxuR',
#   'valZ',
#   'wbbJ',
#   'wecA',
#   'wzzE',
#   'xdhA',
#   'xerD',
#   'xylG',
#   'yadC',
#   'yadE',
#   'yahJ',
#   'yaiW',
#   'yajL',
#   'ybbY',
#   'ybdR',
#   'ybeQ',
#   'ybeT',
#   'ybfA',
#   'ybfL',
#   'ybgD',
#   'ybhG',
#   'ybhP',
#   'ybiA',
#   'ybjE',
#   'ybjP',
#   'ycaI',
#   'ycbL',
#   'yccS',
#   'yccU',
#   'ycdX',
#   'yceO',
#   'ycfT',
#   'ycgB',
#   'ycgG',
#   'ycgR',
#   'yciC',
#   'ycjO',
#   'ydaT',
#   'ydaU',
#   'ydbA',
#   'ydbC',
#   'ydeE',
#   'ydeN',
#   'ydeO',
#   'ydeQ',
#   'ydfJ',
#   'ydfU',
#   'ydgI',
#   'ydhK',
#   'ydhQ',
#   'ydhW',
#   'ydiN',
#   'ydiR',
#   'ydiS',
#   'ydiU',
#   'ydjK',
#   'ydjO',
#   'yeaR',
#   'yebO',
#   'yebZ',
#   'yedE',
#   'yedL',
#   'yeeO',
#   'yegE',
#   'yegK',
#   'yegR',
#   'yegW',
#   'yegX',
#   'yehC',
#   'yehQ',
#   'yeiG',
#   'yeiR',
#   'yeiW',
#   'yejF',
#   'yejH',
#   'yejO',
#   'yfaE',
#   'yfcA',
#   'yfcF',
#   'yfdE',
#   'yfeA',
#   'yfeH',
#   'yfeO',
#   'yfgF',
#   'yfiE',
#   'yfiH',
#   'ygaH',
#   'ygbE',
#   'ygbK',
#   'ygcB',
#   'ygcU',
#   'ygeK',
#   'ygfK',
#   'yghG',
#   'yghO',
#   'ygjI',
#   'ygjQ',
#   'yhaO',
#   'yhbX',
#   'yhcD',
#   'yhgF',
#   'yhhJ',
#   'yhiN',
#   'yhjA',
#   'yidJ',
#   'yihA',
#   'yjcS',
#   'yjgA',
#   'yjhR',
#   'yjjJ',
#   'ykfC',
#   'ylbF',
#   'yncG',
#   'yneE',
#   'yneO',
#   'ynfE',
#   'ynfH',
#   'ypfG',
#   'yphF',
#   'yphG',
#   'ypjI',
#   'yqaB',
#   'yqeA',
#   'yqeC',
#   'yqeG',
#   'yqeK',
#   'yqfA',
#   'yraI',
#   'yrbG',
#   'zapE',
#   'zntR',
#   'zraR'},
#  '12PD': {'hycG',
#   'ecpB',
#   'gltU',
#   'uidC',
#   'cmoB',
#   'rcsC',
#   'aslB',
#   'pheT',
#   'ygeR',
#   'rnd',
#   'trpA',
#   'gltX',
#   'uvrY',
#   'setA',
#   'srlQ',
#   'deoC',
#   'narG',
#   'cydB',
#   'cbdA',
#   'yhhT',
#   'hemN',
#   'yfcU',
#   'gabP',
#   'yqeA',
#   'galE',
#   'yfhM',
#   'betT',
#   'pphA',
#   'ybcL',
#   'prpB',
#   'ygaZ',
#   'yifB',
#   'cysK',
#   'yjbB',
#   'flhB',
#   'dcuC',
#   'glrR',
#   'yeeJ',
#   'proS',
#   'intS',
#   'yeaC',
#   'wza',
#   'ruvA',
#   'aceB',
#   'setB',
#   'mhpC',
#   'garR',
#   'yeaR',
#   'minD',
#   'rpoB',
#   'birA',
#   'ycjU',
#   'pepD',
#   'ybdN',
#   'ptrA',
#   'gltB',
#   'dusC',
#   'ygaY',
#   'yqhG',
#   'yjjJ',
#   'yahN',
#   'adeQ',
#   'ggt',
#   'pstA',
#   'yghX',
#   'purK',
#   'yhcA',
#   'pepA',
#   'trmN',
#   'tpx',
#   'yieP',
#   'cycA',
#   'rsgA',
#   'trmI',
#   'argO',
#   'yciU',
#   'ycbK',
#   'yafX',
#   'dsdC',
#   'nikC',
#   'alaE',
#   'flgD',
#   'ydjI',
#   'peaD',
#   'yagG',
#   'abgR',
#   'pepP',
#   'wcaJ',
#   'yidZ',
#   'hyfG',
#   'ymgC',
#   'dppC',
#   'bcsZ',
#   'ybjE',
#   'yjiT',
#   'oweS',
#   'ygcS',
#   'yqeB',
#   'fre',
#   'yggR',
#   'galP',
#   'ptrB',
#   'mtlA',
#   'yhdP',
#   'thiK',
#   'glnD',
#   'yagK',
#   'dmlR',
#   'argE',
#   'prkB',
#   'flk',
#   'metB',
#   'hisI',
#   'ygiQ',
#   'chaA',
#   'ybiI',
#   'gcl',
#   'cho',
#   'murA',
#   'rhlB',
#   'pflD',
#   'yfeW',
#   'glgB',
#   'bluF',
#   'yecD',
#   'ybjJ',
#   'cynS',
#   'rppH',
#   'yciB',
#   'ydhC',
#   'ybbP',
#   'pheS',
#   'pflB',
#   'opgH',
#   'glpB',
#   'ompX',
#   'argG',
#   'ttcA',
#   'trg',
#   'glnB',
#   'baeS',
#   'nfrA',
#   'bioA',
#   'ulaR',
#   'yebT',
#   'rlmI',
#   'wcaN',
#   'sbcB',
#   'wbbI',
#   'dauA',
#   'mepM',
#   'mltB',
#   'rbbA',
#   'ygfZ',
#   'efeB',
#   'epd',
#   'fabR',
#   'focA',
#   'yafZ',
#   'ybcH',
#   'acs',
#   'rhsC',
#   'ybcM',
#   'arpB',
#   'sgcC',
#   'yfaS',
#   'edd',
#   'garD',
#   'hyaA',
#   'bglX',
#   'pqiB',
#   'mhpA',
#   'ugpE',
#   'valZ',
#   'gntT',
#   'pldA',
#   'zraR',
#   'ybfD',
#   'caiA',
#   'aceE',
#   'fadJ',
#   'nupX',
#   'ydeP',
#   'rnr',
#   'yneO',
#   'yfjX',
#   'mutT',
#   'yniB',
#   'gabT',
#   'wcaD',
#   'bamA',
#   'dtpD',
#   'xisE',
#   'clsA',
#   'mdtF',
#   'cheA',
#   'leuA',
#   'hemX',
#   'yfdP',
#   'ydjN',
#   'cysI',
#   'cspC',
#   'yfdS',
#   'yjjU',
#   'yjcE',
#   'yahD',
#   'rimJ',
#   'yffS',
#   'yibH',
#   'pykA',
#   'chbG',
#   'ydaM',
#   'waaL',
#   'yiaT',
#   'cysJ',
#   'apaH',
#   'rssB',
#   'iclR',
#   'fnr',
#   'yaiS',
#   'acrD',
#   'cvpA',
#   'htpG',
#   'umpH',
#   'tsf',
#   'ugpA',
#   'nanT',
#   'fadL',
#   'sgbE',
#   'fucA',
#   'melA',
#   'rclA',
#   'queD',
#   'yoaH',
#   'ycjM',
#   'pdxK',
#   'aidB',
#   'yjbG',
#   'eptA',
#   'atpG',
#   'rpmG',
#   'kdpC',
#   'yibN',
#   'ecpR',
#   'sspB',
#   'yfgF',
#   'nepI',
#   'murF',
#   'yajO',
#   'alaS',
#   'insC1',
#   'fliH',
#   'mepH',
#   'yfgG',
#   'pdxY',
#   'yhiD',
#   'yraN',
#   'idnT',
#   'gyrA',
#   'arnT',
#   'gltL',
#   'yraQ',
#   'ilvG',
#   'mppA',
#   'dmlA',
#   'argH',
#   'tmcA',
#   'yfhH',
#   'torZ',
#   'ybaO',
#   'fliD',
#   'yjjW',
#   'sdhA',
#   'uidB',
#   'kefC',
#   'ligA',
#   'yehP',
#   'gsiA',
#   'rarD',
#   'djlC',
#   'mcrB',
#   'rho',
#   'ftsB',
#   'tdcA',
#   'mrdB',
#   'nrdF',
#   'ftsN',
#   'trmL',
#   'pgaA',
#   'treB',
#   'hldE',
#   'yrdA',
#   'rbsK',
#   'wcaI',
#   'lpxK',
#   'ybcF',
#   'ydaG',
#   'yceB',
#   'hflD',
#   'yhbE',
#   'ynfM',
#   'ydcK',
#   'xthA',
#   'idnO',
#   'yegI',
#   'fdnI',
#   'yahI',
#   'rutD',
#   'arnB',
#   'kdpD',
#   'dsdA',
#   'abgT',
#   'yegJ',
#   'lhr',
#   'yicG',
#   'yhfZ',
#   'yigM',
#   'yhjA',
#   'sstT',
#   'rluA',
#   'cmtB',
#   'galS',
#   'mukB',
#   'yfhG',
#   'eutK',
#   'tdk',
#   'atoE',
#   'ycgJ',
#   'nmpC',
#   'yfbL',
#   'araA',
#   'uxaA',
#   'galK',
#   'frmB',
#   'ghoS',
#   'uup',
#   'fruB',
#   'aroH',
#   'menB',
#   'sfmH',
#   'sodC',
#   'yhfT',
#   'ybjM',
#   'crp',
#   'flgN',
#   'exbB',
#   'dhaL',
#   'pauD',
#   'ydjX',
#   'yhgE',
#   'serS',
#   'yadV',
#   'nadB',
#   'yciW',
#   'ynjE',
#   'fsr',
#   'dnaT',
#   'fucI',
#   'otsB',
#   'yccU',
#   'exoX',
#   'ygeQ',
#   'dbpA',
#   'codB',
#   'mngB',
#   'tig',
#   'adeD',
#   'lacA',
#   'fadA',
#   'bfd',
#   'gatC',
#   'menF',
#   'lsrC',
#   'yagN',
#   'yebW',
#   'ytfE',
#   'trpR',
#   'glnP',
#   'yciQ',
#   'proB',
#   'tsaA',
#   'yffB',
#   'purL',
#   'yeaN',
#   'yfdF',
#   'fes',
#   'ybbO',
#   'uvrC',
#   'yibQ',
#   'pqiA',
#   'mnaT',
#   'ampG',
#   'yraJ',
#   'yidC',
#   'nagC',
#   'aat',
#   'ynjI',
#   'yebC',
#   'emrK',
#   'frwB',
#   'glrK',
#   'flgL',
#   'poxB',
#   'dcuA',
#   'dcuD',
#   'greA',
#   'plsC',
#   'yphG',
#   'yeaV',
#   'cusA',
#   'yidK',
#   'norV',
#   'purH',
#   'hycE',
#   'ldtC',
#   'yjiR',
#   'ydfI',
#   'rutA',
#   'ppiB',
#   'ybgS',
#   'uhpT',
#   'opgE',
#   'ompG',
#   'yehU',
#   'yfbR',
#   'yphC',
#   'adk',
#   'lepB',
#   'cydA',
#   'frlC',
#   'alsK',
#   'fecA',
#   'fixC',
#   'gstB',
#   'eamB',
#   'atpE',
#   'paaH',
#   'fadI',
#   'infB',
#   'yddA',
#   'oxc',
#   'glpA',
#   'ulaE',
#   'ybhA',
#   'uvrB',
#   'ygcU',
#   'rfbA',
#   'plsX',
#   'lspA',
#   'bcsB',
#   'hyaB',
#   'ygcN',
#   'bglB',
#   'ybiU',
#   'ydbA',
#   'tfaR',
#   'lldP',
#   'orn',
#   'fucO',
#   'yeeZ',
#   'pgm',
#   'zipA',
#   'yagP',
#   'yqcE',
#   'yecE',
#   'fliI',
#   'cohE',
#   'xylB',
#   'yghU',
#   'ysgA',
#   'hsrA',
#   'helD',
#   'codA',
#   'dnaJ',
#   'mdtO',
#   'rimK',
#   'gntP',
#   'ybdR',
#   'hyfJ',
#   'proV',
#   'yfiH',
#   'wcaE',
#   'ecpE',
#   'truA',
#   'msrC',
#   'rpoC',
#   'ycaI',
#   'ycjT',
#   'gspD',
#   'adiY',
#   'hokC',
#   'clcA',
#   'mpaA',
#   'pgsA',
#   'ygeY',
#   'mdtC',
#   'ydeA',
#   'rluC',
#   'yfaL',
#   'fadE',
#   'fliY',
#   'ygeW',
#   'kbaZ',
#   'alsC',
#   'yeeR',
#   'entB',
#   'gntX',
#   'yejB',
#   'purU',
#   'eptB',
#   'yhcN',
#   'opgD',
#   'yadG',
#   'lptE',
#   'proQ',
#   'gstA',
#   'mnmC',
#   'yggI',
#   'ygiS',
#   'acrB',
#   'yojI',
#   'pgaB',
#   'fepB',
#   'ydiK',
#   'frvB',
#   'rbfA',
#   'treA',
#   'yjgX',
#   'rnc',
#   'fecB',
#   'gspJ',
#   'rpoA',
#   'ftsK',
#   'astE',
#   'hyfB',
#   'melR',
#   'lpxT',
#   'yfdQ',
#   'pykF',
#   'ldtD',
#   'gnd',
#   'tyrP',
#   'pitA',
#   'hemB',
#   'gntR',
#   'glyS',
#   'yagH',
#   'yehM',
#   'oppA',
#   'ykgF',
#   'ydiY',
#   'dtpC',
#   'smf',
#   'ssnA',
#   'tqsA',
#   'ypfJ',
#   'uvrA',
#   'menD',
#   'agaW',
#   'yhiJ',
#   'sdhD',
#   'yegQ',
#   'yciV',
#   'msrA',
#   'pyrE',
#   'ldcA',
#   'tauB',
#   'ydcS',
#   'bamC',
#   'ydcV',
#   'cobS',
#   'yhgA',
#   'yeaG',
#   'lepA',
#   'dppA',
#   'yadH',
#   'cusB',
#   'secD',
#   'pawZ',
#   'yacG',
#   'ydaS',
#   'yfjL',
#   'ygfT',
#   'ybhC',
#   'ygeK',
#   'hypE',
#   'wzc',
#   'intZ',
#   'ybgQ',
#   'tnaA',
#   'frmA',
#   'tap',
#   'paaX',
#   'argS',
#   'yneE',
#   'yffQ',
#   'hemY',
#   'yceG',
#   'plsB',
#   'ydfJ',
#   'hydN',
#   'yeaO',
#   'accA',
#   'ydbD',
#   'gmr',
#   'araJ',
#   'queE',
#   'nupG',
#   'ypjI',
#   'fepA',
#   'ydiN',
#   'mutL',
#   'ansP',
#   'sufS',
#   'yqgE',
#   'yhfS',
#   'mscK',
#   'puuA',
#   'asnB',
#   'ycbJ',
#   'ykgP',
#   'yiaB',
#   'aroG',
#   'chaC',
#   'yhjG',
#   'yqeG',
#   'ratB',
#   'torS',
#   'yfgH',
#   'tesB',
#   'yiiM',
#   'potE',
#   'leuT',
#   'pgaC',
#   'rplP',
#   'wcaL',
#   'rrsG',
#   'pyrG',
#   'pka',
#   'mscM',
#   'fumC',
#   'osmC',
#   'yhfY',
#   'slt',
#   'ydiF',
#   'yjgL',
#   'ygcO',
#   'ldrC',
#   'eutB',
#   'mqo',
#   'cyoB',
#   'ygdG',
#   'ybbA',
#   'murJ',
#   'ygaQ',
#   'folE',
#   'pitB',
#   'dcuS',
#   'malP',
#   'ycaL',
#   'purT',
#   'ygeG',
#   'nrdA',
#   'tamA',
#   'trpC',
#   'astD',
#   'deoA',
#   'yccS',
#   'yqiA',
#   'frwA',
#   'rne',
#   'yfeA',
#   'trpD',
#   'ybjP',
#   'yhhH',
#   'yidH',
#   'ltaE',
#   'proA',
#   'ygeV',
#   'copA',
#   'yjiL',
#   'lysA',
#   'flgE',
#   'gntU',
#   'aceF',
#   'ycgN',
#   'btuE',
#   'ypjA',
#   'ygbK',
#   'yebZ',
#   'upp',
#   'artQ',
#   'nohQ',
#   'mazG',
#   'clpB',
#   'sufA',
#   'brnQ',
#   'insJ',
#   'yfdT',
#   'ptsG',
#   'rem',
#   'atpD',
#   'yjfF',
#   'zwf',
#   'ycbX',
#   'fbaB',
#   'glpX',
#   'ghrA',
#   'entF',
#   'ycgV',
#   'hflX',
#   'ssuE',
#   'insA',
#   'ftsE',
#   'ileS',
#   'yceA',
#   'caiT',
#   'hofC',
#   'xapR',
#   'frmR',
#   'gsiC',
#   'aaaE',
#   'uacT',
#   'pnp',
#   'nfrB',
#   'aas',
#   'gapA',
#   'evgS',
#   'iraP',
#   'opgG',
#   'ykfG',
#   'frsA',
#   'yhdX',
#   'melB',
#   'rlmA',
#   'cvrA',
#   'mdtM',
#   'greB',
#   'rhtB',
#   'dld',
#   'yrdE',
#   'arnC',
#   'yiaV',
#   'gspI',
#   'rhsB',
#   'pstB',
#   'livF',
#   'ydcU',
#   'yhjV',
#   'adiA',
#   'citE',
#   'yidG',
#   'yeaP',
#   'relA',
#   'rbsB',
#   'ydaU',
#   'puuP',
#   'yiaG',
#   'rpsA',
#   'pnuC',
#   'dnaX',
#   'yrbG',
#   'ydeS',
#   'yccM',
#   'ydfU',
#   'eptC',
#   'frdA',
#   'mrcB',
#   'ppk',
#   'mrcA',
#   'acpS',
#   'yedY',
#   'yigZ',
#   'nanA',
#   'yjiV',
#   'cyoC',
#   'rhsD',
#   'bisC',
#   'ydeM',
#   'eutL',
#   'phoQ',
#   'sbcC',
#   'yhaB',
#   'prmB',
#   'rph',
#   'ybiW',
#   'hsdR',
#   'mdtK',
#   'dam',
#   'qmcA',
#   'gadB',
#   'rhmT',
#   'yfjK',
#   'ghxP',
#   'mraY',
#   'nirC',
#   'ychH',
#   'yqjD',
#   'yjhB',
#   'ydhQ',
#   'uxuB',
#   'mgtA',
#   'yedJ',
#   'tsaC',
#   'cydC',
#   'speA',
#   'yehH',
#   'feaB',
#   'hrpA',
#   'nagE',
#   'yeeY',
#   'yegT',
#   'ydjL',
#   'yedP',
#   'ypjF',
#   'yaiL',
#   'artJ',
#   'rlmG',
#   'ybhH',
#   'fimI',
#   'yodC',
#   'fepG',
#   'mprA',
#   'yafU',
#   'allC',
#   'yciO',
#   'galM',
#   'gudX',
#   'ygbJ',
#   'idnK',
#   'cyoD',
#   'psuG',
#   'rnlB',
#   'fruK',
#   'glmU',
#   'yqcC',
#   'guaA',
#   'rdgC',
#   'adhE',
#   'rnb',
#   'yafD',
#   'fliF',
#   'ygcE',
#   'ompN',
#   'yafL',
#   'gatR',
#   'manX',
#   'ychO',
#   'acnA',
#   'surA',
#   'scpC',
#   'emrA',
#   'wzyE',
#   'yegR',
#   'yegE',
#   'ftsX',
#   'phoR',
#   'ygbN',
#   'php',
#   'sufC',
#   'feoB',
#   'rihB',
#   'dnaG',
#   'yhgN',
#   'mltD',
#   'yafY',
#   'mutS',
#   'gcvP',
#   'yicT',
#   'rplE',
#   'katE',
#   'stfR',
#   'tdcC',
#   'rlmD',
#   'asnW',
#   'rrrQ',
#   'leuP',
#   'rsmB',
#   'ycjW',
#   'yagE',
#   'leuQ',
#   'allS',
#   'purF',
#   'rihC',
#   'hchA',
#   'rhsE',
#   'ybfQ',
#   'fepD',
#   'yrdD',
#   'dmsA',
#   'cspD',
#   'pepQ',
#   'dinQ',
#   'yncL',
#   'pmrD',
#   'yiiE',
#   'adeP',
#   'ycgB',
#   'rpoD',
#   'ydbH',
#   'yfcO',
#   'paaE',
#   'ppsR',
#   'nagB',
#   'livM',
#   'ygfK',
#   'aroM',
#   'yhhM',
#   'lrp',
#   'modC',
#   'cstA',
#   'radA',
#   'caiF',
#   'lit',
#   'aroE',
#   'cyoA',
#   'yjcC',
#   'rhaR',
#   'mrdA',
#   'kup',
#   'yjbQ',
#   'fumA',
#   'sucA',
#   'nikA',
#   'yfeX',
#   'rsmE',
#   'caiE',
#   'deoB',
#   'folM',
#   'flhC',
#   'bcsA',
#   'dosP',
#   'tfaD',
#   'nadR',
#   'yicN',
#   'yicH',
#   'grxB',
#   'rutG',
#   'yfdL',
#   'lptA',
#   'sfmD',
#   'rpsJ',
#   'cysM',
#   'ybjO',
#   'mukE',
#   'nhaA',
#   'ypdC',
#   'yqeF',
#   'ychF',
#   'guaB',
#   'wcaC',
#   'ftnB',
#   'cyaA',
#   'yehQ',
#   'narZ',
#   'yfeH',
#   'ppc',
#   'yfcD',
#   'nrdG',
#   'cadC',
#   'qorA',
#   'prfB',
#   'thiC',
#   'aldB',
#   'yciE',
#   'lon',
#   'nrdE',
#   'cadA',
#   'sdaA',
#   'yfiF',
#   'mfd',
#   'ydiV',
#   'yehD',
#   'gsiB',
#   'fimH',
#   'prpC',
#   'sdhB',
#   'cirA',
#   'metK',
#   'puuC',
#   'dsbD',
#   'ygiF',
#   'fimA',
#   'tyrS',
#   'mdlB',
#   'yagF',
#   'recC',
#   'ybhJ',
#   'mmuM',
#   'smrA',
#   'rhmA',
#   'ibsE',
#   'rspA',
#   'fbaA',
#   'gyrB',
#   'zapB',
#   'sbmA',
#   'ftsI',
#   'yfaQ',
#   'tktB',
#   ...},
#  'OCTA': {'acnA',
#   'acnB',
#   'acpP',
#   'acrB',
#   'adeD',
#   'adiY',
#   'aer',
#   'anmK',
#   'arpA',
#   'asmA',
#   'bcr',
#   'bglB',
#   'bioB',
#   'caiF',
#   'cbdB',
#   'chaA',
#   'cheY',
#   'clsA',
#   'crp',
#   'csiE',
#   'cspE',
#   'cydX',
#   'dauA',
#   'deoA',
#   'dld',
#   'dmsA',
#   'dnaC',
#   'dusB',
#   'ecpC',
#   'elbB',
#   'emrA',
#   'eutP',
#   'fabF',
#   'fabI',
#   'ffh',
#   'fhuC',
#   'fieF',
#   'flgD',
#   'frdA',
#   'frvR',
#   'fumB',
#   'gadC',
#   'gapC',
#   'glnD',
#   'glpX',
#   'gltB',
#   'gltX',
#   'gspI',
#   'gstA',
#   'gtrS',
#   'hfq',
#   'hns',
#   'hokE',
#   'hscA',
#   'hybG',
#   'hycE',
#   'intE',
#   'intF',
#   'iraD',
#   'iraM',
#   'katG',
#   'leuQ',
#   'lit',
#   'lplT',
#   'mdtC',
#   'metG',
#   'metJ',
#   'mglA',
#   'mlaA',
#   'mmuM',
#   'mnmG',
#   'mraZ',
#   'mrdB',
#   'mreB',
#   'mreC',
#   'mscK',
#   'msrB',
#   'mutS',
#   'nagA',
#   'nfsA',
#   'nirC',
#   'norV',
#   'nrdE',
#   'ompF',
#   'opgD',
#   'opgE',
#   'oppA',
#   'pdxK',
#   'pepA',
#   'pgm',
#   'proS',
#   'ptsN',
#   'purL',
#   'puuR',
#   'pyrE',
#   'rbbA',
#   'recE',
#   'relA',
#   'rep',
#   'rhlE',
#   'rho',
#   'rlmH',
#   'rnr',
#   'rplJ',
#   'rplQ',
#   'rpoA',
#   'rpoC',
#   'rrrQ',
#   'rsxG',
#   'sapA',
#   'sapB',
#   'sapD',
#   'sbmC',
#   'sbp',
#   'sdaA',
#   'setB',
#   'trg',
#   'trkH',
#   'ttdT',
#   'tynA',
#   'ubiB',
#   'ugpC',
#   'uidC',
#   'uup',
#   'uxuA',
#   'wcaD',
#   'wcaN',
#   'xthA',
#   'yacL',
#   'yaeI',
#   'yagF',
#   'yahI',
#   'yahN',
#   'yaiC',
#   'yaiL',
#   'yaiS',
#   'yajR',
#   'ybbJ',
#   'ybfQ',
#   'ybhB',
#   'ybjJ',
#   'ycfQ',
#   'yciA',
#   'yciQ',
#   'ydaG',
#   'ydaM',
#   'ydbA',
#   'ydbH',
#   'ydcI',
#   'yddW',
#   'ydjG',
#   'yeaO',
#   'yeeJ',
#   'yehQ',
#   'yejO',
#   'yfcZ',
#   'ygaZ',
#   'ygfK',
#   'yhcG',
#   'yhfS',
#   'yhgE',
#   'yicH',
#   'yihQ',
#   'yjgN',
#   'yjhQ',
#   'yliI',
#   'yneO',
#   'ynfH',
#   'ynfO',
#   'yqhG',
#   'yrdE',
#   'zntA'}}

# %%
print(
    "A total of",
    len(set.union(*strain_to_all_genes.values())),
    "genes are mutated."
)
# Out:
# A total of 2031 genes are mutated.

# %%
# Hypermutators are strains with mutations in a mutX gene
hypermutators = [s for s, genes in strain_to_genes.items() if "mut" in set(g[:3] for g in genes)]
non_hypermutators = set(strain_to_genes) - set(hypermutators)

# %%
print(
    "There are",
    len(non_hypermutators),
    "non-mutator strains with a total of",
    len(set.union(*[v for k, v in strain_to_muts.items() if k in non_hypermutators])),
    "mutations affecting",
    len(set.union(*[v for k, v in strain_to_all_genes.items() if k in non_hypermutators])),
    "genes."
)
# Out:
# There are 192 non-mutator strains with a total of 929 mutations affecting 366 genes.

# %%
with open("../Data/Mutation_data/Strain_to_genes.json", "w") as outfile:
    json.dump({k: list(v) for k, v in strain_to_genes.items() if k in non_hypermutators}, outfile)
    
with open("../Data/Mutation_data/Strain_to_all_genes.json", "w") as outfile:
    json.dump({k: list(v) for k, v in strain_to_all_genes.items() if k in non_hypermutators}, outfile)
    
with open("../Data/Mutation_data/All_strains_to_gene_names.json", "w") as outfile:
    json.dump({k: list(v) for k, v in strain_to_genes.items()}, outfile)
    
with open("../Data/Mutation_data/All_strains_to_mutations.json", "w") as outfile:
    json.dump({k: list(v) for k, v in strain_to_muts.items()}, outfile)
    
with open("../Data/Mutation_data/All_mutated_genes.txt", "w") as outfile:
    mutated_genes = set.union(*[strain_to_genes[s] for s in non_hypermutators])
    outfile.write("\n".join(mutated_genes))
    
with open("../Data/Mutation_data/Mutations_to_gene_names.json", "w") as outfile:
    json.dump({k: v for k, v in mut_to_genes.items()}, outfile)

# %%
print("Number of mutations in each of the strains classified as a hypermutator:")
for s in sorted(hypermutators):
    print(s, len(strain_to_genes[s]), sep=" \t")
# Out:
# Number of mutations in each of the strains classified as a hypermutator:
# 12PD1-10 	134
# 12PD1-2 	146
# 12PD1-4 	112
# 12PD2-8 	157
# 12PD2-9 	158
# 12PD3-10 	147
# 12PD3-7 	134
# 12PD3-8 	179
# 12PD4-8 	93
# 12PD4-9 	94
# 12PD5-1 	132
# 12PD5-3 	132
# 12PD7-5 	108
# 12PD7-6 	193
# 12PD8-10 	154
# 12PD8-6 	151
# 12PD8-7 	136
# 23BD3-3 	280
# 23BD3-4 	241
# 23BD3-9 	263
# ADIP5-2 	215
# ADIP5-6 	181
# HMDA4-2 	45
# HMDA4-6 	47
# HMDA4-9 	44
# HMDA6-3 	85
# HMDA6-7 	87
# IBUA3-2 	42
# OCTA6-5 	106
# OCTA6-6 	107
# OCTA6-7 	109

# %%
mutation_dict = {s: set(m for m in muts if not m.startswith("DUP")) for s, muts in strain_to_muts.items()}
bins = np.bincount([len(mutation_dict[s]) for s in non_hypermutators])
plt.bar(np.array(range(len(bins))) - 0.4, bins, color="darkgreen")
plt.xlabel("Mutations per strain")
plt.ylabel("Count")
plt.xlim(0, 26)
# Out:
# (0.0, 26.0)

# %%
mutation_dict = {s: set(m for m in muts if not m.startswith("DUP")) for s, muts in strain_to_muts.items()}
bins = np.bincount([len(mutation_dict[s]) for s in non_hypermutators if s != "GLUT7-7"])
plt.bar(np.array(range(len(bins))) - 0.4, bins, color="darkgreen")
plt.xlabel("Mutations per strain", fontsize=24)
plt.ylabel("Count", fontsize=24)
plt.xlim([0, 12])
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.savefig("../Plots/Supplementary - Strain mutation histogram.svg")

# %%
num_dups = [len([m for m in muts if m.startswith("DUP")]) for s, muts in strain_to_muts.items() if s in non_hypermutators]
bins = np.bincount(num_dups)
plt.bar(np.array(range(len(bins))) - 0.4, bins, color="darkgreen")
plt.xlabel("Duplications per strain", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.ylim([0, 140])
plt.xlim([0, 40])
#plt.savefig("../Plots/Supplementary - Strain duplication histogram.svg")
# Out:
# (0.0, 40.0)

# %%
duplication_lengths = {}
for s, muts in strain_to_muts.items():
    dup_sum = 0
    for mut in muts:
        if mut.startswith("DUP"):
            dup_sum += int("".join(mut.split("-")[2].split("_")[0].split(",")))
    duplication_lengths[s] = dup_sum
